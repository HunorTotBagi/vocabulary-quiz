# %%
import random

def create_dictionary_from_txt(txt_file):
    translation_dict = {}

    with open(txt_file, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()

            if line:
                source_word, target_word = line.split(' - ')
                translation_dict[source_word.strip()] = target_word.strip()

    return translation_dict

def the_test(dictionary):
    score = 0
    wrong_answers = []
    wrong_answers_input = []
    
    keys_list = list(dictionary.keys())
    random.shuffle(keys_list)

    for key in keys_list:        
        while True:
            print("\nHilfe: Ä, ä, Ö, ö, Ü, ü, ß\n")
            print("Das nächste Wort ist:", key)
            user_input = input("Ins Deutsche übersetzen: ").strip()
            print()

            if user_input:
                break
            else:
                print("Sie haben nichts eingegeben, versuchen Sie es erneut.\n")

        correct_answer = dictionary[key]

        if user_input != correct_answer:
            print("Falsche Antwort!")
            print("-----------------------")
            wrong_answers.append(key)
            wrong_answers_input.append(user_input)
        else:
            score += 1
            print("Richtig!")
            print("-----------------------")

    total = len(keys_list)
    final_score = round((score / total) * 100)
    print("\n*********************\n")
    print(f"Sie hatten {score} von {total} Punkten. Dein Ergebnis ist {final_score}%.")
    print("\n*********************")

    if not wrong_answers:
        print("\nDU HAST DEN TEST OHNE FEHLER BESTANDEN!\n")
    else:
        print("\nDeine Fehler:\n")
        for i, (key, user_input) in enumerate(zip(wrong_answers, wrong_answers_input), 1):
            print(f"{i}) {key} - {dictionary[key]}")
            print(f"   Deine Antwort: {user_input}\n")

# %%
dict_01 = create_dictionary_from_txt('database/B-1.1-wörter/1-stunde.txt')
dict_02 = create_dictionary_from_txt('database/B-1.1-wörter/2-stunde.txt')

# %%
# dict_01 - 80%, 100%, 100%
# dict_02 - 58%, 

the_test(dict_02)
# Out:
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: fraza / izreka
# Ins Deutsche übersetzen: 654
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: svesno
# Ins Deutsche übersetzen: wussen
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: koristiti
# Ins Deutsche übersetzen: einzusetzen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: razlika
# Ins Deutsche übersetzen: der Unterschied
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: tečno
# Ins Deutsche übersetzen: fließend
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: strani jezik
# Ins Deutsche übersetzen: die Fremdsprache
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: svi
# Ins Deutsche übersetzen: alle
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: zbog toga
# Ins Deutsche übersetzen: deswegen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: sporazumjeti se
# Ins Deutsche übersetzen: sich asd
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: razraditi
# Ins Deutsche übersetzen: asd
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: teško pasti
# Ins Deutsche übersetzen: swerigallen
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: drugačiji
# Ins Deutsche übersetzen: unterschiedlich
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: neophodno
# Ins Deutsche übersetzen: notwendig
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: završeci
# Ins Deutsche übersetzen: die Endungen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: sve
# Ins Deutsche übersetzen: alles
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: osim toga
# Ins Deutsche übersetzen: außerdem
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: pravi prijatelji
# Ins Deutsche übersetzen: eche freunde
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: osim
# Ins Deutsche übersetzen: außer
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: nesvesno
# Ins Deutsche übersetzen: unwe...
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: predmet
# Ins Deutsche übersetzen: das Fach
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: razlika u godinama
# Ins Deutsche übersetzen: das Altersunterschied
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: nekoga upoznati
# Ins Deutsche übersetzen: jemanden kennenlernen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: izgovor
# Ins Deutsche übersetzen: aussprache
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: primeniti
# Ins Deutsche übersetzen: anwenden
#
# Richtig!
# -----------------------
#
# *********************
#
# Sie hatten 14 von 24 Punkten. Dein Ergebnis ist 58%.
#
# *********************
#
# Deine Fehler:
#
# 1) fraza / izreka - die Redewendung
#    Deine Antwort: 654
#
# 2) svesno - bewusst
#    Deine Antwort: wussen
#
# 3) strani jezik - Die Fremdsprache
#    Deine Antwort: die Fremdsprache
#
# 4) sporazumjeti se - sich verständigen
#    Deine Antwort: sich asd
#
# 5) razraditi - erarbeiten
#    Deine Antwort: asd
#
# 6) teško pasti - schwerfällt
#    Deine Antwort: swerigallen
#
# 7) pravi prijatelji - wahre Freunde
#    Deine Antwort: eche freunde
#
# 8) nesvesno - unbewusst
#    Deine Antwort: unwe...
#
# 9) razlika u godinama - der Altersunterschied
#    Deine Antwort: das Altersunterschied
#
# 10) izgovor - die Aussprache
#    Deine Antwort: aussprache
