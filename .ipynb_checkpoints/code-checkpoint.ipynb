# %%
import random

def create_dictionary_from_txt(txt_file):
    # Initialize an empty dictionary to store translations.
    translation_dict = {}

    # Open the specified text file for reading, using UTF-8 encoding.
    with open(txt_file, 'r', encoding='utf-8') as file:
        # Iterate through each line in the file.
        for line in file:
            # Remove leading and trailing whitespace from the line.
            line = line.strip()

            # Check if the line is not empty.
            if line:
                # Split the line into source and target words using ' - ' as a separator.
                source_word, target_word = line.split(' - ')

                # Add the translation to the dictionary, stripping any extra whitespace.
                translation_dict[source_word.strip()] = target_word.strip()

    # Return the populated translation dictionary.
    return translation_dict

# %%
# Creating dictionaries
dict_01 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-15/15-arbeitsbuch.txt')
dict_02 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-15/15-buch.txt')
dict_03 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-15/15-buch-oben.txt')
dict_04 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-15/15-notizen.txt')

dict_05 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-16/16-arbeitsbuch.txt')
dict_06 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-16/16-buch.txt')
dict_07 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-16/16-buch-oben.txt')
dict_08 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-16/16-notizen.txt')

dict_09 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-17/17-arbeitsbuch.txt')
dict_10 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-17/17-buch.txt')
dict_11 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-17/17-buch-oben.txt')
dict_12 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-17/17-notizen.txt')

dict_13 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-18/18-arbeitsbuch.txt')
dict_14 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-18/18-buch.txt')
dict_15 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-18/18-buch-oben.txt')
dict_16 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-18/18-notizen.txt')

dict_17 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-19/19-arbeitsbuch.txt')
dict_18 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-19/19-buch.txt')
dict_19 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-19/19-buch-oben.txt')
dict_20 = create_dictionary_from_txt('database/A-2.2-wörter/lekcion-19/19-notizen.txt')

# %%
def the_test(dictionary):
    # Initialize the user's score, a list to store wrong answers, and another list for corresponding user inputs.
    score = 0
    wrong_answers = []
    wrong_answers_input = []
    
    # Create a list of keys from the input dictionary and shuffle them randomly.
    keys_list = list(dictionary)
    random.shuffle(keys_list)

    # Iterate through the shuffled keys.
    for key in keys_list:        
        user_input_bool = True
        while user_input_bool:
            # Prompt the user with the next word to translate.
            print(" ")
            print("Hilfe: Ä, ä, Ö, ö, Ü, ü, ß")
            print(" ")
            print("Das nächste Wort ist:", key)
            # Get the user's translation input in German.
            print(" ")
            user_input = input("Ins Deutsche übersetzen: ").strip()  # Use strip() to remove leading/trailing spaces.
            print(" ")

            # Check if the user input is not empty.
            if user_input != "":
                user_input_bool = False  # Exit the loop when non-empty input is provided.
            else:
                print("Sie haben nichts eingegeben, versuchen Sie es erneut.")
                print(" ")

        # Check if the correct translation contains no spaces (single word).
        if dictionary[key].count(" ") == 0:
            # Compare user input with the correct translation.
            if user_input != dictionary[key]:
                # Print "Falsche Antwort!" (Wrong answer!) and record the mistake.
                print("Falsche Antwort!")
                print("-----------------------")
                wrong_answers.append(key)
                wrong_answers_input.append(user_input)
            else:
                # If correct, increase the score and print "Richtig!" (Correct!).
                score += 1
                print("Richtig!")
                print("-----------------------")
        else:
            # If the correct translation contains spaces (phrase), split both the correct and user inputs.
            first, second = dictionary[key].split(" ")
            
            # Check if the user input contains no spaces (single word).
            if user_input.count(" ") == 0:
                # Compare the second part of the correct translation with user input.
                if second == user_input:
                    # If correct, increase the score.
                    score += 1
                else:
                    # Print "Falsche Antwort!" and record the mistake.
                    print("Falsche Antwort!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)
            else:
                # If both the correct and user inputs contain spaces, split them further.
                first_input, second_input = user_input.split(" ")
                
                # Compare both parts of the correct translation with user inputs.
                if first == first_input and second == second_input:
                    # If correct, increase the score.
                    score += 1
                    print("Richtig!")
                    print("-----------------------")
                elif first != first_input and second == second_input:
                    # If the first part is incorrect but the second is correct, give half points.
                    score += 0.5
                    print("Halb Richtig!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)
                else:
                    # Print "Falsche Antwort!" and record the mistake.
                    print("Falsche Antwort!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)

    # Calculate the final score as a percentage.
    final_score = int((round(score / len(keys_list), 2)) * 100)
    print("*********************")
    print(" ")
    # Print the user's score and percentage.
    print(f"Sie hatten {score} von {len(keys_list)} Punkten. Dein Ergebnis ist {final_score}%.")
    print(" ")
    print("*********************")
    
    # Check if there were no wrong answers.
    if len(wrong_answers) == 0:
        # If no mistakes, print a success message.
        print(" ")
        print("DU HAST DEN TEST OHNE FEHLER BESTANDEN!")
        print(" ")
    else:
        print(" ")
        print("Deine Fehler:")
        print(" ")
        # Iterate through wrong answers and display them along with the correct translations.
        for i in range(len(wrong_answers_input)):
            print(f"{i}) {wrong_answers[i]} - {dictionary[wrong_answers[i]]}")
            print(f"Deine Antwort: {wrong_answers_input[i]}")
            print(" ")

# %%
# Lekcion 15

# dict_01 - 46%, 56%,
# dict_02 - 10%, 37%,
# dict_03 - 56%, 78%,
# dict_04 - 36%, 55%,

# the_test(dict_04)

# %%
# Lekcion 16

# dict_05 - 26%, 50%, 
# dict_06 - 50%, 11%,
# dict_07 - 69%, 73%, 100%, 96%.
# dict_08 - 14%, 59%, 

# the_test(dict_08)

# %%
# Lekcion 17

# dict_09 - 69%, 66%, 57%, 84%, 92%.
# dict_10 - 43%, 50%, 43%, 64%, 100%.
# dict_11 - 67%, 75%, 75%, 83%, 100%.
# dict_12 - 83%, 17%, 33%, 67%, 100%.

# the_test(dict_12)

# %%
# Lekcion 18

# dict_13 - 48%, 53%, 85%, 95%, 94%.
# dict_14 - 23%, 18%, 32%, 82%, 91%.
# dict_15 - 10%, 10%, 70%, 100%, 100%.
# dict_16 - 53%, 53%, 72%, 92%, 97%.

# the_test(dict_14)

# %%
# Lekcion 19

# dict_17 - 17%, 67%, 100%,
# dict_18 - 10%, 66%, 76%,
# dict_19 - 40%, 71%, 92%,
# dict_20 - 47%, 77%, 87%,

the_test(dict_20)
# Out:
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: izvanredan, odlican
#
# Ins Deutsche übersetzen: ausgezeichnen
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: nastaviti sa
#
# Ins Deutsche übersetzen: weitermachen mit
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: odakle
#
# Ins Deutsche übersetzen: woher
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: kazna
#
# Ins Deutsche übersetzen: die Streife
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: proveriti
#
# Ins Deutsche übersetzen: überprüfen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: paziti na
#
# Ins Deutsche übersetzen: aufpassen auf
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: ubediti nekoga
#
# Ins Deutsche übersetzen: jemanden überzeugen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: ishrana
#
# Ins Deutsche übersetzen: die Ernährung
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: pesnik
#
# Ins Deutsche übersetzen: der Dichter
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: čuvati
#
# Ins Deutsche übersetzen: aufbewaren
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: duša
#
# Ins Deutsche übersetzen: die Seele
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: gde
#
# Ins Deutsche übersetzen: wo
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: kuda
#
# Ins Deutsche übersetzen: wohin
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: volja
#
# Ins Deutsche übersetzen: der Wille
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: oduševiti
#
# Ins Deutsche übersetzen: begeistern
#
# Richtig!
# -----------------------
# *********************
#
# Sie hatten 13 von 15 Punkten. Dein Ergebnis ist 87%.
#
# *********************
#
# Deine Fehler:
#
# 0) izvanredan, odlican - ausgezeichnet
# Deine Antwort: ausgezeichnen
#
# 1) kazna - die Strafe
# Deine Antwort: die Streife
