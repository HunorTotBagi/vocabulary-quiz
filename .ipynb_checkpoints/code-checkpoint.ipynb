# %%
import random

def create_dictionary_from_txt(txt_file):
    translation_dict = {}

    with open(txt_file, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()

            if line:
                source_word, target_word = line.split(' - ')
                translation_dict[source_word.strip()] = target_word.strip()

    return translation_dict

def the_test(dictionary):
    score = 0
    wrong_answers = []
    wrong_answers_input = []
    
    keys_list = list(dictionary.keys())
    random.shuffle(keys_list)

    for key in keys_list:        
        while True:
            print("\nHilfe: Ä, ä, Ö, ö, Ü, ü, ß\n")
            print("Das nächste Wort ist:", key)
            user_input = input("Ins Deutsche übersetzen: ").strip()
            print()

            if user_input:
                break
            else:
                print("Sie haben nichts eingegeben, versuchen Sie es erneut.\n")

        correct_answer = dictionary[key]

        if user_input != correct_answer:
            print("Falsche Antwort!")
            print("-----------------------")
            wrong_answers.append(key)
            wrong_answers_input.append(user_input)
        else:
            score += 1
            print("Richtig!")
            print("-----------------------")

    total = len(keys_list)
    final_score = round((score / total) * 100)
    print("\n*********************\n")
    print(f"Sie hatten {score} von {total} Punkten. Dein Ergebnis ist {final_score}%.")
    print("\n*********************")

    if not wrong_answers:
        print("\nDU HAST DEN TEST OHNE FEHLER BESTANDEN!\n")
    else:
        print("\nDeine Fehler:\n")
        for i, (key, user_input) in enumerate(zip(wrong_answers, wrong_answers_input), 1):
            print(f"{i}) {key} - {dictionary[key]}")
            print(f"   Deine Antwort: {user_input}\n")

# %%
dict_01 = create_dictionary_from_txt('database/B-1.1-wörter/1-stunde.txt')
dict_02 = create_dictionary_from_txt('database/B-1.1-wörter/2-stunde.txt')
dict_03 = create_dictionary_from_txt('database/B-1.1-wörter/3-stunde.txt')

# %%
# dict_01 - 80%, 100%, 100%
# dict_02 - 58%, 
# dict_03 - 40%, 53%, 67%, 93% || 87%

the_test(dict_03)
# Out:
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: pripremiti se
# Ins Deutsche übersetzen: sich vorbereiten
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: sporazumeti se
# Ins Deutsche übersetzen: sich verständigen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: upoznati
# Ins Deutsche übersetzen: kennenlernen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: ne odustaj
# Ins Deutsche übersetzen: gib nicht auf
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: imenovati
# Ins Deutsche übersetzen: nennen
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: primetiti
# Ins Deutsche übersetzen: merken
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: reč
# Ins Deutsche übersetzen: das Wort
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: napamet naučiti
# Ins Deutsche übersetzen: aufwendig lernen
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: izuzeci
# Ins Deutsche übersetzen: die Ausnahme
#
# Falsche Antwort!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: reči
# Ins Deutsche übersetzen: die Wörter
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: na kraju dana
# Ins Deutsche übersetzen: am Ende des Tages
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: proširiti
# Ins Deutsche übersetzen: erweitern
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: zapisivati
# Ins Deutsche übersetzen: aufschreiben
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: vokabular
# Ins Deutsche übersetzen: der Wortschatz
#
# Richtig!
# -----------------------
#
# Hilfe: Ä, ä, Ö, ö, Ü, ü, ß
#
# Das nächste Wort ist: baviti se sa
# Ins Deutsche übersetzen: sich beschäftigen mit
#
# Richtig!
# -----------------------
#
# *********************
#
# Sie hatten 13 von 15 Punkten. Dein Ergebnis ist 87%.
#
# *********************
#
# Deine Fehler:
#
# 1) napamet naučiti - auswendig lernen
#    Deine Antwort: aufwendig lernen
#
# 2) izuzeci - die Ausnahmen
#    Deine Antwort: die Ausnahme
