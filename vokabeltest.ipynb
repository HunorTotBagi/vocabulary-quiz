# %%
import random

def create_dictionary_from_txt(txt_file):
    # Initialize an empty dictionary to store translations.
    translation_dict = {}

    # Open the specified text file for reading, using UTF-8 encoding.
    with open(txt_file, 'r', encoding='utf-8') as file:
        # Iterate through each line in the file.
        for line in file:
            # Remove leading and trailing whitespace from the line.
            line = line.strip()

            # Check if the line is not empty.
            if line:
                # Split the line into source and target words using ' - ' as a separator.
                source_word, target_word = line.split(' - ')

                # Add the translation to the dictionary, stripping any extra whitespace.
                translation_dict[source_word.strip()] = target_word.strip()

    # Return the populated translation dictionary.
    return translation_dict

# %%
# Creating dictionaries
dict_1 = create_dictionary_from_txt('database/01_cas_1.txt')
dict_2 = create_dictionary_from_txt('database/02_cas_2.txt')
dict_3 = create_dictionary_from_txt('database/03_cas_3.txt')
dict_4 = create_dictionary_from_txt('database/04_radna_sveska_1.txt')
dict_5 = create_dictionary_from_txt('database/05_radna_sveska_2.txt')
dict_6 = create_dictionary_from_txt('database/06_cas_4.txt')
dict_7 = create_dictionary_from_txt('database/07_cas_5.txt')
dict_8 = create_dictionary_from_txt('database/08_lekcija_4.txt')
dict_9 = create_dictionary_from_txt('database/09_cas_6.txt')
dict_10 = create_dictionary_from_txt('database/10_lekcija_5.txt')
dict_11 = create_dictionary_from_txt('database/11_cas_7.txt')
dict_12 = create_dictionary_from_txt('database/12_lekcija_6.txt')

# %%
# Define a function 'the_test' that takes a dictionary 'dict' as input.
def the_test(dict):
    # Initialize the user's score, a list to store wrong answers, and another list for corresponding user inputs.
    score = 0
    wrong_answers = []
    wrong_answers_input = []
    
    # Create a list of keys from the input dictionary and shuffle them randomly.
    keys_list = list(dict)
    random.shuffle(keys_list)

    # Iterate through the shuffled keys.
    for key in keys_list:
        # Prompt the user with the next word to translate.
        print("Das nächste Wort ist: ", key)
        
        # Get the user's translation input in German.
        user_input = input("Ins Deutsche übersetzen: ")
        print(" ")

        # Check if the correct translation contains no spaces (single word).
        if dict[key].count(" ") == 0:
            # Compare user input with the correct translation.
            if user_input != dict[key]:
                # Print "Falsche Antwort!" (Wrong answer!) and record the mistake.
                print("Falsche Antwort!")
                print("-----------------------")
                wrong_answers.append(key)
                wrong_answers_input.append(user_input)
            else:
                # If correct, increase the score and print "Richtig!" (Correct!).
                score += 1
                print("Richtig!")
                print("-----------------------")
        else:
            # If the correct translation contains spaces (phrase), split both the correct and user inputs.
            first, second = dict[key].split(" ")
            
            # Check if the user input contains no spaces (single word).
            if user_input.count(" ") == 0:
                # Compare the second part of the correct translation with user input.
                if second == user_input:
                    # If correct, increase the score.
                    score += 1
                else:
                    # Print "Falsche Antwort!" and record the mistake.
                    print("Falsche Antwort!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)
            else:
                # If both the correct and user inputs contain spaces, split them further.
                first_input, second_input = user_input.split(" ")
                
                # Compare both parts of the correct translation with user inputs.
                if first == first_input and second == second_input:
                    # If correct, increase the score.
                    score += 1
                    print("Richtig!")
                    print("-----------------------")
                elif first != first_input and second == second_input:
                    # If the first part is incorrect but the second is correct, give half points.
                    score += 0.5
                    print("Halb Richtig!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)
                else:
                    # Print "Falsche Antwort!" and record the mistake.
                    print("Falsche Antwort!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)

    # Calculate the final score as a percentage.
    final_score = int((round(score / len(keys_list), 2)) * 100)
    print("*********************")
    print(" ")
    # Print the user's score and percentage.
    print(f"Sie hatten {score} von {len(keys_list)} Punkten.")
    print(f"Dein Ergebnis ist {final_score}%.")
    print(" ")
    print("*********************")
    
    # Check if there were no wrong answers.
    if len(wrong_answers) == 0:
        # If no mistakes, print a success message.
        print("DU HAST DEN TEST OHNE FEHLER BESTANDEN!")
    else:
        print(" ")
        print("Deine Fehler:")
        print(" ")
        # Iterate through wrong answers and display them along with the correct translations.
        for i in range(len(wrong_answers_input)):
            print(f"{i}) {wrong_answers[i]} - {dict[wrong_answers[i]]}")
            print(f"Deine Antwort: {wrong_answers_input[i]}")
            print(" ")

# %%
the_test(dict_12)
# Out:
# Das nächste Wort ist:  umetnost
# Ins Deutsche übersetzen: die Kunst
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  odbor za diskusiju
# Ins Deutsche übersetzen: das Diskussionrunde
#
# Falsche Antwort!
# -----------------------
# Das nächste Wort ist:  događaj
# Ins Deutsche übersetzen: das Veranstaltung
#
# Halb Richtig!
# -----------------------
# Das nächste Wort ist:  koncert
# Ins Deutsche übersetzen: das Konzert
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  zvezda (tv)
# Ins Deutsche übersetzen: die Star
#
# Halb Richtig!
# -----------------------
# Das nächste Wort ist:  popust
# Ins Deutsche übersetzen: das Ermäßigung
#
# Halb Richtig!
# -----------------------
# Das nächste Wort ist:  žurka
# Ins Deutsche übersetzen: das Fest
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  umetnik
# Ins Deutsche übersetzen: der Künstler
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  ulaznica
# Ins Deutsche übersetzen: der Eintrittskarte
#
# Halb Richtig!
# -----------------------
# Das nächste Wort ist:  ulaz
# Ins Deutsche übersetzen: der Eintritt
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  festival
# Ins Deutsche übersetzen: das Festival
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  predstava
# Ins Deutsche übersetzen: die Theaterstück
#
# Halb Richtig!
# -----------------------
# Das nächste Wort ist:  prezentacija
# Ins Deutsche übersetzen: der Vortrag
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  bina
# Ins Deutsche übersetzen: die Bühne
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  izložba
# Ins Deutsche übersetzen: der Ausstellung
#
# Halb Richtig!
# -----------------------
# *********************
#
# Sie hatten 11.0 von 15 Punkten.
# Dein Ergebnis ist 73%.
#
# *********************
#
# Deine Fehler:
#
# 0) odbor za diskusiju - die Diskussionsrunde
# Deine Antwort: das Diskussionrunde
#
# 1) događaj - die Veranstaltung
# Deine Antwort: das Veranstaltung
#
# 2) zvezda (tv) - der Star
# Deine Antwort: die Star
#
# 3) popust - die Ermäßigung
# Deine Antwort: das Ermäßigung
#
# 4) ulaznica - die Eintrittskarte
# Deine Antwort: der Eintrittskarte
#
# 5) predstava - das Theaterstück
# Deine Antwort: die Theaterstück
#
# 6) izložba - die Ausstellung
# Deine Antwort: der Ausstellung
