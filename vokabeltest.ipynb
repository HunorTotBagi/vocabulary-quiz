# %%
import random

dict_1 = {}

# Prvi čas
dict_1["opisati"] = "beschreiben"
dict_1["rođak"] = "der Cousin"
dict_1["rođaka"] = "die Cousine"
dict_1["tetka, ujna"] = "die Tante"
dict_1["opisati"] = "beschreiben"
dict_1["rođak"] = "der Cousin"
dict_1["rođaka"] = "die Cousine"
dict_1["tetka, ujna"] = "die Tante"
dict_1["ujak"] = "der Onkel"
dict_1["tašta, svekrva"] = "die Schwiegermutter"
dict_1["tast"] = "der Schwiegervater"
dict_1["zet"] = "der Schwiegersohn"
dict_1["snaja"] = "die Schwiegertochter"
dict_1["maćeha"] = "die Stiefmutter"
dict_1["očuh"] = "der Stiefvater"
dict_1["polu sestra"] = "die Stiefschwester"
dict_1["polu brat"] = "der Stiefbruder"
dict_1["sa majčine strane"] = "mütterlicherseits"
dict_1["sa očeve strane"] = "väterlicherseits"
dict_1["političar"] = "der Politiker"
dict_1["vodoinstalater"] = "der Klempner"
dict_1["čitati naglas"] = "vorlesen"
dict_1["kolekcija"] = "die Sammlung"
dict_1["nećak"] = "der Neffe"
dict_1["nećaka"] = "die Nichte"
dict_1["zagonetka"] = "das Rätsel"
dict_1["gluposti"] = "Quatsch"

dict_2 = {}

# Drugi čas
dict_2["smisao"] = "der Sinn"
dict_2["apartman"] = "die Wohnung"
dict_2["selidba"] = "der Umzug"
dict_2["urediti"] = "einrichten"
dict_2["uređenje"] = "die Einrichtung"

dict_3 = {}

# Treci čas
dict_3["pre nečega"] = "bevor"
dict_3["stara gradnja"] = "der Altbau"
dict_3["nova gradnja"] = "der Neubau"
dict_3["ukus"] = "der Geschmack"
dict_3["sakriti"] = "verstecken"
dict_3["stvari"] = "die Dinge"
dict_3["stvar"] = "das Ding"
dict_3["pokrivač, plafon"] = "die Decke"
dict_3["svetlo"] = "das Licht"
dict_3["inače"] = "sonst"
dict_3["uređaj"] = "das Gerät"
dict_3["predmet"] = "der Gegenstand"
dict_3["domaćinstvo"] = "der Haushalt"
dict_3["materijal"] = "das Stoff"
dict_3["provoditi"] = "verbringen"
dict_3["oporavak"] = "die Erholung"
dict_3["mir"] = "die Ruhe"

dict_4 = {}

# Reči iz radne sveske - 1
dict_4["priča, istorija"] = "die Geschichte"
dict_4["omladina"] = "der Jugendliche"
dict_4["lutka"] = "die Puppe"
dict_4["igra"] = "das Spiel"
dict_4["vic"] = "der Witz"
dict_4["popeti se"] = "klettern"
dict_4["sakupljati"] = "sammeln"
dict_4["raspravljati"] = "streiten"
dict_4["prenoćiti"] = "übernachten"
dict_4["prodati"] = "verkaufen"
dict_4["crtati"] = "zeichnen"
dict_4["lud"] = "verrückt"
dict_4["ranije"] = "früher"
dict_4["početak"] = "der Anfang"
dict_4["u početku"] = "am Anfang"
dict_4["kraj"] = "das Ende"
dict_4["na kraju"] = "am Ende"
dict_4["tim"] = "die Mannschaft"
dict_4["biber"] = "der Pfeffer"
dict_4["tačka, poen"] = "der Punkt"
dict_4["rečenica"] = "der Satz"
dict_4["otvoriti"] = "aufmachen"
dict_4["paziti"] = "aufpassen"
dict_4["uspeti"] = "klappen"
dict_4["desiti se"] = "passieren"
dict_4["rasti"] = "wachsen"
dict_4["zatovoreno"] = "geschlossen"

dict_5 = {}

# Reči iz radne sveske - 2
dict_5["ćošak"] = "die Ecke"
dict_5["tv"] = "das Fernsehgerät"
dict_5["šporet"] = "der Herd"
dict_5["jastuk"] = "das Kissen"
dict_5["prostor"] = "der Raum"
dict_5["polica"] = "das Regal"
dict_5["pisaći sto"] = "der Schreibtisch"
dict_5["vrata"] = "die Tür"
dict_5["zavesa"] = "der Vorhang"
dict_5["zid"] = "die Wand"
dict_5["alat"] = "das Werkzeug"
dict_5["visiti"] = "hängen"
dict_5["sveska"] = "das Heft"

dict_6 = {}

# Četvrti čas
dict_6["svetlo"] = "das Licht"
dict_6["more"] = "das Meer"
dict_6["reka"] = "der Fluss"
dict_6["država (L)"] = "der Land"
dict_6["država (S)"] = "der Staat"
dict_6["luka"] = "der Hafen"
dict_6["planina"] = "der Berg"
dict_6["kuće"] = "die Häuser"
dict_6["magla"] = "der Nebel"
dict_6["svuda"] = "überall"
dict_6["reklame"] = "die Werbung"
dict_6["opuštanje"] = "die Entspannung"
dict_6["doživeti"] = "erleben"
dict_6["farma"] = "der Bauernhof"
dict_6["uživati"] = "genießen"
dict_6["ponuda"] = "das Angebot"
dict_6["iskustvo"] = "die Erfahrung"
dict_6["pored toga"] = "außerdem"
dict_6["prijaviti se"] = "sich anmelden"
dict_6["javiti se"] = "sich Melden"
dict_6["vetar"] = "der Wind"
dict_6["početnik"] = "der Anfänger"
dict_6["napredni (čovek)"] = "der Fortgeschrittene"
dict_6["napor"] = "die Anstrengung"
dict_6["posavetovati"] = "beraten"
dict_6["oprema"] = "die Ausrüstung"
dict_6["komarac"] = "die Mücke"
dict_6["nudi"] = "bietet"
dict_6["ponašati se"] = "sich benehmen"
dict_6["znojiti se"] = "schwitzen"
dict_6["iskreno"] = "ehrlich"
dict_6["povezati"] = "verbinden"
dict_6["izgubiti"] = "verlieren"
dict_6["lopov"] = "der Dieb"
dict_6["lopovi"] = "die Diebe"
dict_6["krađa"] = "der Diebstahl"
dict_6["peh"] = "das Pech"

dict_7 = {}

# Peti čas
dict_7["spisak za kupovinu (ez)"] = "der Einkaufszettel"
dict_7["spisak za kupovinu (el)"] = "die Einkaufsliste"
dict_7["držati"] = "halten"
dict_7["nositi"] = "tragen"
dict_7["kolica za kupovinu"] = "der Einkaufswagen"
dict_7["korpa za kupovinu"] = "der Einkaufskorb"
dict_7["po potrebi"] = "nach bedarf"
dict_7["štedljiv"] = "sparsam"
dict_7["kasica prasica"] = "die Sparkasse"
dict_7["štedeti"] = "sparen"
dict_7["uštedeti"] = "einsparen"
dict_7["navika"] = "die Gewohnheit"
dict_7["koverat"] = "der Briefumschlag"
dict_7["tuna"] = "der Thunfisch"
dict_7["salama"] = "der Salami"
dict_7["breskva"] = "der Pfirsich"
dict_7["ledeni čaj"] = "der Eistee"
dict_7["paprika"] = "die Paprika"
dict_7["beli luk"] = "der Knoblauch"
dict_7["banana"] = "die Banane"
dict_7["kruška"] = "die Birne"
dict_7["sok"] = "der Saft"
dict_7["pasulj"] = "die Bohne"
dict_7["brašno"] = "das Mehl"
dict_7["džem"] = "die Marmelade"
dict_7["sitan sir"] = "der Quark"
dict_7["kola"] = "die Cola"
dict_7["bombona"] = "das Bonbon"

def the_test(dict):
    score = 0
    wrong_answers = []
    wrong_answers_input = []
    
    keys_list = list(dict)
    random.shuffle(keys_list)

    for key in keys_list:

        print("Das nächste Wort ist: ",key)
        user_input = input("Ins Deutsche übersetzen: ")
        print(" ")

        if dict[key].count(" ") == 0:
            if user_input != dict[key]:
                print("Falsche Antwort!")
                print("-----------------------")
                wrong_answers.append(key)
                wrong_answers_input.append(user_input)
            else:
                score += 1
                print("Richtig!")
                print("-----------------------")
        else:
            first, second = dict[key].split(" ")
            if user_input.count(" ") == 0:
                if second == user_input:
                    score += 1
                else:
                    print("Falsche Antwort!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)
            else:
                first_input, second_input = user_input.split(" ")
                if first == first_input and second == second_input:
                    score += 1
                    print("Richtig!")
                    print("-----------------------")
                elif first != first_input and second == second_input:
                    score += 0.5
                    print("Halb Richtig!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)
                else:
                    print("Falsche Antwort!")
                    print("-----------------------")
                    wrong_answers.append(key)
                    wrong_answers_input.append(user_input)

    print(" ")
    final_score = int((round(score / len(keys_list),2))*100)
    print("*********************")
    print(f"Sie hatten {score} von {len(keys_list)} Punkten.")
    print(f"Dein Ergebnis ist {final_score}%.")
    print("*********************")
    
    if len(wrong_answers) == 0:
        print("DU HAST DEN TEST OHNE FEHLER BESTANDEN!")
    else:
        print(" ")
        print("Deine Fehler:")
        print(" ")
        for i in range(len(wrong_answers_input)):
            print(f"{i}) {wrong_answers[i]} - {dict[wrong_answers[i]]}")
            print(f"Deine Antwort: {wrong_answers_input[i]}")
            print(" ")

# %%
the_test(dict_7)
# Out:
# Das nächste Wort ist:  spisak za kupovinu (ez)
# Ins Deutsche übersetzen: der Einkaufszettel
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  štedljiv
# Ins Deutsche übersetzen: sparsam
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  spisak za kupovinu (el)
# Ins Deutsche übersetzen: die Einkaufsliste
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  koverat
# Ins Deutsche übersetzen: der Briefumschlag
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  korpa za kupovinu
# Ins Deutsche übersetzen: der Einkaufskorb
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  kolica za kupovinu
# Ins Deutsche übersetzen: der Einkaufswagen
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  po potrebi
# Ins Deutsche übersetzen: nach bedarf
#
# Richtig!
# -----------------------
# Das nächste Wort ist:  nositi
# Ins Deutsche übersetzen: tragen
#
# Richtig!
# -----------------------
# ...
